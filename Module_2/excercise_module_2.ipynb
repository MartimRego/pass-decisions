# %% [markdown]
# # 📘 Session 2: Playing Style & Role Representation — Exercises

# %% [markdown]
# ## 🏟️ Part A. Playing Style Clusters
#
# ### Task A1. Plot the possession embeddings (PC1 vs PC2) for all teams.
#
# - Color by style_cluster.
#
# - Which clusters look like direct transitions vs tiki-taka?

# %%
# HINT:
sns.scatterplot(data=df_possessions, x="PC1", y="PC2", hue="style_cluster", alpha=0.4)

# %% [markdown]
# ### Task A2. Pick two Premier League teams and compare their style distributions.
#
# - Who relies more on direct play?
#
# - Who prefers slow buildup?

# %%
# HINT:
team_styles.loc[["Arsenal","Newcastle United"]].plot(kind="bar", stacked=True)

# %% [markdown]
# ### Task A3. Which match shows the largest difference in style mix between two teams?
#
# - Think about “possession fingerprints” at the match level.

# %%
# HINT: group by (match_id, team) and compare proportions

# %% [markdown]
# # 🧩 Part B. Player Role Embeddings
#
# ## Task B1. Pick a midfielder (e.g., Rodri).
#
# 1. Plot him on the t-SNE map.
#
# 2. Who are his nearest neighbors in embedding space?
#
#    similar_to_rodri = find_similar_players("Rodri", top_n=5)
# print(similar_to_rodri)
#
#
# ## Task B2. Repeat the exercise for a striker (e.g., Haaland).
#
# 1. Who plays most similarly in terms of possession role?
#
# 2. Does the similarity match your football intuition?
#
# ## Task B3. Visualize two players from different archetypes on the same map (e.g., Ødegaard vs Casemiro).
#
# - What makes their embeddings different?
#
# # 🎭 Part C. Role Archetypes
#
# ## Task C1. Look at the summary of archetype clusters.
#
# 1. Which cluster has the longest average possession duration?
#
# 2. Which cluster progresses the ball furthest forward?
#
# role_summary
#
#
# ## Task C2. Pick your favorite player.
#
# 1. Identify his archetype cluster.
#
# L2. ist 5 other players in the same role family.
#
# cluster_id = player_roles.loc["Bukayo Saka","role_cluster"]
# player_roles[player_roles["role_cluster"] == cluster_id].head()
#
#
# ## Task C3. (Challenge) Within each archetype, rank players by possession progressiveness (net_progress_x).
#
# - Who is the most progressive ball-carrier in each role family?
#
# # 🏁 Wrap-Up Reflection
#
# - Which teams showed the biggest contrast in possession style?
#
# - Which player similarity surprised you the most?
#
# - Do the role archetypes match your intuition about how players play?
